# %%
# %reload_ext autoreload
# %autoreload 2

import pandas as pd
from practice_data_sets.loader import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from practice_data_sets.visualize import DataVisualizer

# %%
#add the data

data_loader = DataLoader("Weather Training Data.csv")
df = data_loader.load_data()

# print(df.dtypes)
# print(df.head())
# print(df["MaxTemp"].isna().sum())

# %%
(df.head())
# Out:
#   row ID Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   Row0   Albury     13.4     22.9       0.6          NaN       NaN
# 1   Row1   Albury      7.4     25.1       0.0          NaN       NaN
# 2   Row2   Albury     17.5     32.3       1.0          NaN       NaN
# 3   Row3   Albury     14.6     29.7       0.2          NaN       NaN
# 4   Row4   Albury      7.7     26.7       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2           W           41.0        ENE  ...        82.0         33.0
# 3         WNW           56.0          W  ...        55.0         23.0
# 4           W           35.0        SSE  ...        48.0         19.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
visualizer = DataVisualizer(df)

visualizer.display_average_max_temperature_by_location()


locations = df["Location"].unique()
visualizer.display_temperature_distribution_for_location(locations)
#visualizer.display_rainfall_distribution_for_location(["Albury", "Walpole", "Salt lake city"])

#visualizer.display_rainfall_vs_temperature()
#visualizer.display_wind_speed_vs_temp_change()
#visualizer.display_evaporation_vs_sunshine()
# Out:
# float64
# 60455    28.5
# 27482    28.5
# 93963    17.2
# 69702    37.3
# 68548    23.3
# 21803    15.9
# 94572    31.9
# 76167    18.0
# 77242    19.0
# 97371    32.3
# Name: MaxTemp, dtype: float64
# <string>:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
